# %%
import pandas as pd
df=pd.read_csv("C:\\Users\pc\\Downloads\\best_cs_scientist_details (1).csv")
df.head(8)
# Out:
#    World Rank  National Rank               Name  \
# 0           1              1       Anil K. Jain
# 1           2              1      Yoshua Bengio
# 2           3              2         Jiawei Han
# 3           4              1   Andrew Zisserman
# 4           5              3  Michael I. Jordan
# 5           6              5    Thomas S. Huang
# 6           7              4       Philip S. Yu
# 7           8              6       Takeo Kanade
#
#                                           Image URLs  \
# 0  https://s.research.com/images/2a967b4499197336...
# 1  https://s.research.com/images/aec914cd458a74e2...
# 2  https://s.research.com/images/42382fdef4ef0953...
# 3  https://s.research.com/images/2a3913cff9795e86...
# 4  https://s.research.com/images/aa9fe06f07349099...
# 5  https://s.research.com/images/ddd0e184e7830de1...
# 6  https://s.research.com/images/20815a3765631eb9...
# 7  https://s.research.com/images/6f00a60e4fcd5fbf...
#
# ...

# %% [markdown]
# # Describing

# %%
df.describe()
# Out:
#         World Rank  National Rank      H-Index      Citations        #DBLP
# count  1000.000000    1000.000000  1000.000000    1000.000000  1000.000000
# mean    500.500000     184.679000    83.923000   42247.296000   350.913000
# std     288.819436     189.696818    18.114613   41373.209175   185.752592
# min       1.000000       1.000000    67.000000   12697.000000    82.000000
# 25%     250.750000      17.000000    71.000000   22125.500000   224.000000
# 50%     500.500000      93.500000    78.000000   30671.000000   310.000000
# 75%     750.250000     343.250000    91.000000   47544.500000   420.250000
# max    1000.000000     593.000000   201.000000  637950.000000  1584.000000

# %% [markdown]
# # Dataset Information

# %%
info=df.info()
info
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   World Rank     1000 non-null   int64
#  1   National Rank  1000 non-null   int64
#  2   Name           1000 non-null   object
#  3   Image URLs     1000 non-null   object
#  4   Affiliation    1000 non-null   object
#  5   Country        1000 non-null   object
#  6   H-Index        1000 non-null   int64
#  7   Citations      1000 non-null   int64
#  8   #DBLP          1000 non-null   int64
# dtypes: int64(5), object(4)
# memory usage: 70.4+ KB

# %% [markdown]
# # Check Outliers

# %%
import seaborn as sns
sns.boxplot(df)
# Out:
# <Axes: >

# %% [markdown]
# # Missing Value

# %%
missing_value =df.fillna(0)
missing_value
# Out:
#      World Rank  National Rank               Name  \
# 0             1              1       Anil K. Jain
# 1             2              1      Yoshua Bengio
# 2             3              2         Jiawei Han
# 3             4              1   Andrew Zisserman
# 4             5              3  Michael I. Jordan
# ..          ...            ...                ...
# 995         996            592   Jayaram K. Udupa
# 996         997            591      Xiang-Gen Xia
# 997         998            593   Julia Hirschberg
# 998         999             35       Leif Kobbelt
# 999        1000             91   Kwang-Ting Cheng
#
#                                             Image URLs  \
# 0    https://s.research.com/images/2a967b4499197336...
# 1    https://s.research.com/images/aec914cd458a74e2...
# 2    https://s.research.com/images/42382fdef4ef0953...
# 3    https://s.research.com/images/2a3913cff9795e86...
# 4    https://s.research.com/images/aa9fe06f07349099...
# ...

# %% [markdown]
# # Mode Value

# %%
median_value=df.median()
median_value
# Out:
# C:\Users\pc\AppData\Local\Temp\ipykernel_4664\3252211207.py:1: FutureWarning: The default value of numeric_only in DataFrame.median is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   median_value=df.median()
# World Rank         500.5
# National Rank       93.5
# H-Index             78.0
# Citations        30671.0
# #DBLP              310.0
# dtype: float64

# %% [markdown]
# # Mean Value

# %%
mean_value=df.mean()
mean_value
# Out:
# C:\Users\pc\AppData\Local\Temp\ipykernel_4664\1962160015.py:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   mean_value=df.mean()
# World Rank         500.500
# National Rank      184.679
# H-Index             83.923
# Citations        42247.296
# #DBLP              350.913
# dtype: float64

# %% [markdown]
# # Median Value

# %%
median_value=df.median()
median_value
# Out:
# C:\Users\pc\AppData\Local\Temp\ipykernel_4664\3252211207.py:1: FutureWarning: The default value of numeric_only in DataFrame.median is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   median_value=df.median()
# World Rank         500.5
# National Rank       93.5
# H-Index             78.0
# Citations        30671.0
# #DBLP              310.0
# dtype: float64
